# %%
import pandas as pd

# %%
data = {
  'Name': ["Amit", "Ravi", "Sita"],
  'Age': [20, 22, 21],
  'Marks': [85, 90, 88],
  'Student_ID': [101, 102, 105],
  'Math': [88, 92, 85],
  'English': [85, 90, 91],
  'Science': [90, 88, 88],
};

# %%
df = pd.DataFrame(data)
df

# %% [markdown]
# DATA INSPECTION

# %%
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# Other dataSet for Practice

# %%
import pandas as pd
import numpy as np

# Create a larger dataset with missing values for practice
practical_data = {
    'Student_ID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'Name': ['Alice', 'Bob', 'Charlie', np.nan, 'Eve', 'Frank', np.nan, 'Hannah', 'Ian', 'Julia'],
    'Age': [20, 22, 21, 23, 21, np.nan, 22, 20, 23, np.nan],
    'Math': [88, 92, 78, 95, 85, 90, np.nan, 88, 91, 87],
    'Science': [90, 88, 85, 92, 88, np.nan, 89, 91, np.nan, 85],
    'English': [85, 90, 88, 89, 91, 92, 86, np.nan, 88, 90],
    'History': [np.nan, 85, 80, 88, 82, 87, 85, 86, 89, np.nan]
}

practical_df = pd.DataFrame(practical_data)
practical_df

# %%
practical_df.isnull().sum()
