# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.3.3

# %% [markdown]
# ## For the series in pandas

# %%
data=pd.Series([1,2,3,4,5])
print(data)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# Above these is default index places

# %%
data=pd.Series([1,2,3,4,5],index=['a','b','c','d','e']  )
print(data)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %% [markdown]
# Above we labled with our need
