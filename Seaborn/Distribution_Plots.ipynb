# %% [markdown]
# ### Distribution Plots

# %% [markdown]
# univariant set

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=sns.load_dataset('tips')
data.sample()
# Out:
#    total_bill   tip   sex smoker  day    time  size
# 3       23.68  3.31  Male     No  Sun  Dinner     2

# %% [markdown]
# - distplot() ke jagah displot() use hota hai New version mai

# %%
sns.distplot(data["total_bill"], bins=20, kde=True)
plt.show()
# Out:
# C:\Users\mithu\AppData\Local\Temp\ipykernel_11728\4259131311.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["total_bill"], bins=20, kde=True)

# %%
sns.displot(data["tip"], bins=20, kde=True,color='red')
plt.show()
