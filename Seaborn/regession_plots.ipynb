# %% [markdown]
# - regplot() "regression plot" : It plots data and a linear regression model fit.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.regplot(data=tips, x="total_bill", y="tip")
plt.show()
