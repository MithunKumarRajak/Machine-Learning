# %% [markdown]
# ### Matplotlib plotted line
#
# Use the keyword argument linestyle, or shorter ls, to change the style of the plotted line:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.array([1,2,3,4,5])
y=np.array([10,8,6,4,2])

plt.plot(x, y, linestyle='dotted')
plt.show()

# %% [markdown]
# Shorter SyntaxThe line style can be written in a shorter syntax:
#
# linestyle can be written as ls
#
# dotted can be written as :
#
# dashed can be written as --

# %%
x=np.array([1,2,3,4,5])
y=np.array([10,8,6,4,2])

plt.plot(x, y, linestyle='dashed',color='g')
plt.show()

# %% [markdown]
# Line Color
#
# You can use the keyword argument color or the shorter c to set the color of the line:

# %% [markdown]
# Line Width
#
# You can use the keyword argument linewidth or the shorter lw to change the width of the line.
#
# The value is a floating number - 20.2

# %%
x=np.array([1,2,3,4,5])
y=np.array([10,8,6,4,2])

plt.plot(x, y, linestyle='-',linewidth=15)
plt.show()

# %%
x1 = np.array([0, 1, 2, 3])
x2 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
y2 = np.array([61, 12, 17, 11])

plt.plot(x1,y1, linestyle='dashed', color='r', linewidth = 5)
plt.plot(x2,y2, linestyle='dashed', color='b', linewidth = 5)

plt.show()
