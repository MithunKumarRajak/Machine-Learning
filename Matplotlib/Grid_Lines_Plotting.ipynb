# %% [markdown]
# #### Grid Lines in the Plotting
#
# With Pyplot, you can use the grid() function to add grid lines to the plot.

# %%
print('__version__')
# Out:
# __version__

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.array([1,2,3,4,5])
y=np.array([10,8,6,4,2])


plt.xlabel("X AXIS")
plt.ylabel("Y AXIS")
plt.title("SIMPLE PLOT")

plt.grid(color='c', linestyle='--', linewidth=1.5)

plt.plot(x,y, color='m', marker='o', markersize=10, markerfacecolor='b')
# plt.show()
