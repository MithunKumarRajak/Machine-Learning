# %% [markdown]
# ### Matplotlib Markers
#
# we can use the keyword argument marker to emphasize each point

# %% [markdown]
# like maker = 'D'

# %% [markdown]
# Marker	Description
#
# 'o'	Circle
#
# '*'	Star
#
# '.'	Point
#
# ','	Pixel
#
# 'x'	X
#
# 'X'	X (filled)
#
# '+'	Plus
#
# 'P'	Plus (filled)
#
# 's'	Square
#
# 'D'	Diamond
#
# 'd'	Diamond (thin)
#
# 'p'	Pentagon
#
# 'H'	Hexagon
#
# 'h'	Hexagon
#
# 'v'	Triangle Down
#
# '^'	Triangle Up
#
# '<'	Triangle Left
#
# '>'	Triangle Right
#
# '1'	Tri Down
#
# '2'	Tri Up
#
# '3'	Tri Left
#
# '4'	Tri Right
#
# '|'	Vline
#
# '_'	Hline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# point 1,1 2,2 and 3,3 without line
x=np.array([1,3,2])
y=np.array([1,3,2])
plt.plot(x,y ,'o')
plt.show()

# %%
x=np.array([5,3,2])
y=np.array([1,3,2])
plt.plot(x,y,marker='d')
plt.show()

# %% [markdown]
# ## marker| line| color

# %% [markdown]
# Line Syntax	Description
#
# '-'	Solid line
#
# ':'	Dotted line
#
# '--'	Dashed line
#
# '-.'	Dashed/dotted line

# %% [markdown]
# ### Color Reference
# Color Syntax	Description
#
# 'r'	Red
#
# 'g'	Green
#
# 'b'	Blue
#
# 'c'	Cyan
#
# 'm'	Magenta
#
# 'y'	Yellow
#
# 'k'	Black
#
# 'w'	White

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:c')
plt.show()

# %% [markdown]
# * Marker Size
#
# You can use the keyword argument markersize or the shorter version, ms to set the size of the markers

# %%
ypoints = np.array([3, 8, 5, 7, 10])

plt.plot(ypoints, marker = 'o', markersize = 50)
plt.show()

# %% [markdown]
# ### Marker Color
# You can use the keyword argument markeredgecolor or the shorter 'mec' to set the color of the edge of the markers:

# %%
ypoints = np.array([43, 8, 15, 10])

plt.plot(ypoints, marker = 'o', ms = 32, mec = 'm')
plt.show()

# %% [markdown]
# You can use the keyword argument 'markerfacecolor' or the shorter 'mfc' to set the color inside the edge of the markers:

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'p', ms = 45, markerfacecolor = 'y')
plt.show()

# %% [markdown]
# ### Use both the mec and mfc arguments to color the entire marker:

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 10, markersize = 15, markeredgecolor = 'y', markerfacecolor = 'm')
plt.show()
