# %% [markdown]
# # Cleaning Data of Wrong Format

# %% [markdown]
# Two options:

# %% [markdown]
# We have two options: remove the rows, or convert all cells in the columns into the same format.

# %%
import pandas as pd

df = pd.read_csv('DataSet/fitness_data.csv')
pd.to_datetime(df['Date'], format='mixed')

print(df.to_string())

# %% [markdown]
# ##### Removing Rows

# %%
df.dropna(subset=['Date'], inplace=True)
print(df.to_string())
