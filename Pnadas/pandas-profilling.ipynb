# %%
print("Hi")
# Out:
# Hi

# %%
import pandas as pd
df =pd.read_csv("../Dataset\playtennis.csv")
df.head()
# Out:
#     Outlook Temperature Humidity    Wind PlayTennis
# 0     Sunny         Hot     High    Weak         No
# 1  Overcast        Mild   Normal  Strong         No
# 2  Overcast        Cool   Normal     NaN        Yes
# 3      Rain        Mild     High  Strong         No
# 4      Rain         Hot   Normal    Weak        Yes

# %%
# from pandas_profiling import ProfileReport # old version not working
from ydata_profiling import ProfileReport # new version
profile = ProfileReport(df)
profile.to_file("pandas_profile_output.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
